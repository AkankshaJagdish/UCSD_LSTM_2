# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import os
from os import listdir
from os.path import isdir, join
from PIL import Image
import matplotlib.pyplot as plt

# Configuration
class Config:
    DATASET_PATH = "UCSD_Anomaly_Dataset.v1p2/UCSDped1/Train"
    SINGLE_TEST_PATH = "UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test/Test032"
    TEST_DATA_PATH = "UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test"
    BATCH_SIZE = 2
    EPOCHS = 3
    MODEL_PATH = "model_lstm.pth"
    EARLY_STOPPING_PATIENCE = 5  # Stop if validation loss doesn't improve for 5 epochs

# %%
def simple_progress_bar(iteration, total, bar_length=50):
    progress = (iteration / total)
    arrow = '-' * int(round(progress * bar_length) - 1) + '>'
    spaces = ' ' * (bar_length - len(arrow))

    print('\r[{}] {}/{} ({:.2f}%)'.format(arrow + spaces, iteration, total, progress * 100), end='')

# %%
from os import listdir
from os.path import isfile, join, isdir
from PIL import Image
import numpy as np
import shelve
def get_clips_by_stride(stride, frames_list, sequence_size):
    """ For data augmenting purposes.
    Parameters
    ----------
    stride : int
        The desired distance between two consecutive frames
    frames_list : list
        A list of sorted frames of shape 128 X 128
    sequence_size: int
        The size of the desired LSTM sequence
    Returns
    -------
    list
        A list of clips, 10 frames each
    """
    clips = []
    sz = len(frames_list)
    clip = np.zeros(shape=(sequence_size, 128, 128, 1))
    cnt = 0
    for start in range(0, stride):
        for i in range(start, sz, stride):
            clip[cnt, :, :, 0] = frames_list[i]
            cnt = cnt + 1
            if cnt == sequence_size:
                clips.append(np.copy(clip))
                cnt = 0
    return clips



def get_training_set():
    clips = []
    for f in sorted(listdir(Config.DATASET_PATH)):
        if isdir(join(Config.DATASET_PATH, f)):
            all_frames = []
            for c in sorted(listdir(join(Config.DATASET_PATH, f))):
                if str(join(join(Config.DATASET_PATH, f), c))[-3:] == "tif":
                    img = Image.open(join(join(Config.DATASET_PATH, f), c)).resize((128, 128))  # Reduced image size
                    img = np.array(img, dtype=np.float32) / 128.0
                    all_frames.append(img)
            for stride in range(1, 3):
                clips.extend(get_clips_by_stride(stride=stride, frames_list=all_frames, sequence_size=10))
    return np.array(clips)  # Convert list to numpy array before tensor conversion

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision.transforms import ToTensor

# %%
class ConvLSTMCell(nn.Module):
    def __init__(self, input_size, hidden_size, kernel_size):
        super(ConvLSTMCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.kernel_size = kernel_size
        self.padding = kernel_size // 2
        self.conv = nn.Conv2d(input_size + hidden_size, 4 * hidden_size, kernel_size, 1, self.padding)

    def forward(self, x, state):
        h_cur, c_cur = state
        combined = torch.cat([x, h_cur], dim=1)
        gates = self.conv(combined)
        ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)
        ingate = torch.sigmoid(ingate)
        forgetgate = torch.sigmoid(forgetgate)
        cellgate = torch.tanh(cellgate)
        outgate = torch.sigmoid(outgate)

        c_next = (forgetgate * c_cur) + (ingate * cellgate)
        h_next = outgate * torch.tanh(c_next)

        return h_next, c_next
    
    def initialize_hidden_state(self, batch_size, image_size):
        height, width = image_size
        return (torch.zeros(batch_size, self.hidden_size, height, width, device=self.conv.weight.device),
                torch.zeros(batch_size, self.hidden_size, height, width, device=self.conv.weight.device))

# %%
class ConvLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, kernel_size, num_layers):
        super(ConvLSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.kernel_size = kernel_size
        self.num_layers = num_layers
        self._all_layers = []
        for i in range(0, self.num_layers):
            cur_input_dim = self.input_size if i == 0 else self.hidden_size
            cell = ConvLSTMCell(input_size=cur_input_dim,
                                hidden_size=self.hidden_size,
                                kernel_size=self.kernel_size)
            self._all_layers.append(cell)
            self.add_module('cell_{}'.format(i), cell)

    def forward(self, x, hidden_state=None):
        internal_state = []
        outputs = []
        for step in range(x.size(1)):
            x_t = x[:, step, :, :, :]
            for i in range(self.num_layers):
                # get or initialize the internal state
                if hidden_state is None:
                    h, c = self._all_layers[i].initialize_hidden_state(batch_size=x_t.size(0), image_size=(x_t.size(2), x_t.size(3)))
                else:
                    h, c = hidden_state[i]
                h, c = self._all_layers[i](x_t, [h, c])
                x_t = h
                if i == (self.num_layers - 1):
                    outputs.append(h)
            internal_state.append([h, c])

        layer_output = torch.stack(outputs, dim=1)
        return layer_output, internal_state

# %%
class AnomalyDetectionModel(nn.Module):
    def __init__(self):
        super(AnomalyDetectionModel, self).__init__()
        # Encoder
        self.encoder_time_distributed_conv1 = nn.Conv2d(1, 128, kernel_size=11, stride=4, padding=5)
        self.encoder_time_distributed_conv2 = nn.Conv2d(128, 64, kernel_size=5, stride=2, padding=2)
        self.encoder_conv_lstm1 = ConvLSTM(64, 64, kernel_size=3, num_layers=1)
        self.encoder_conv_lstm2 = ConvLSTM(64, 32, kernel_size=3, num_layers=1)
        self.encoder_conv_lstm3 = ConvLSTM(32, 64, kernel_size=3, num_layers=1)

        # Decoder
        self.decoder_time_distributed_conv_transpose1 = nn.ConvTranspose2d(64, 64, kernel_size=5, stride=2, padding=2, output_padding=1)
        self.decoder_time_distributed_conv_transpose2 = nn.ConvTranspose2d(64, 128, kernel_size=11, stride=4, padding=2, output_padding=1)
        self.decoder_time_distributed_conv3 = nn.Conv2d(128, 1, kernel_size=10, padding=3)



    def forward(self, x):
        # Reshape to handle time distributed operations
        b, t, h, w, c = x.size()
        x = x.view(b*t, c, h, w)
        
        # Encoder
        x = self.encoder_time_distributed_conv1(x)
        
        x = self.encoder_time_distributed_conv2(x)
        
        # Reshape for LSTM layers
        x = x.view(b, t, x.size(1), x.size(2), x.size(3))
        
        x, _ = self.encoder_conv_lstm1(x)
        
        x, _ = self.encoder_conv_lstm2(x)
        
        x, _ = self.encoder_conv_lstm3(x)

        # Reshape for decoder conv layers
        x = x.view(b*t, x.size(2), x.size(3), x.size(4))
        
        # Decoder
        x = self.decoder_time_distributed_conv_transpose1(x)
        
        x = self.decoder_time_distributed_conv_transpose2(x)
        
        x = self.decoder_time_distributed_conv3(x)

        x = x[:, :, :128, :128]

        # Reshape back to original shape
        x = x.view(b, t, h, w, c)
        
        return x

# %%
def train_model(model, train_loader, optimizer, criterion, device, epochs):
    model.train()
    best_loss = float('inf')
    stopping_counter = 0

    epochs = epochs
    
    for epoch in range(epochs):
        epoch_loss = 0.0
        for sequences in train_loader:
            print(f"Type of sequences: {type(sequences)}, Structure: {sequences}")
            sequences = sequences.to(device)
            optimizer.zero_grad()
            b, t, h, w, c = sequences.size()
            sequences_reshaped = sequences.view(b*t, c, h, w)
            outputs = model(sequences)
            loss = criterion(outputs.view(b*t, c, h, w), sequences_reshaped)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()

        avg_epoch_loss = epoch_loss / len(train_loader)
        print(f"Epoch [{epoch+1}/{Config.EPOCHS}], Loss: {avg_epoch_loss:.4f}")

        # Early stopping based on training loss
        if avg_epoch_loss < best_loss:
            best_loss = avg_epoch_loss
            torch.save(model.state_dict(), Config.MODEL_PATH)
            stopping_counter = 0
        else:
            stopping_counter += 1
            if stopping_counter == Config.EARLY_STOPPING_PATIENCE:
                print("Early stopping triggered.")
                break

def get_model(reload_model=True):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = AnomalyDetectionModel().to(device)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    criterion = nn.MSELoss()
    epochs = Config.EPOCHS

    if reload_model:
        model.load_state_dict(torch.load(Config.MODEL_PATH))
        model.eval()
    else:
        training_set = get_training_set()
        training_set = torch.tensor(training_set).float()
        # DataLoader with num_workers
        train_loader = DataLoader(training_set, batch_size=Config.BATCH_SIZE, shuffle=True, num_workers=4)  # num_workers set to 4
        train_model(model, train_loader, optimizer, criterion, device, epochs)
        torch.save(model.state_dict(), Config.MODEL_PATH)

    return model


def get_single_test():
    sz = 200
    test = np.zeros(shape=(sz, 128, 128, 1))
    cnt = 0
    for f in sorted(listdir(Config.SINGLE_TEST_PATH)):
        if str(join(Config.SINGLE_TEST_PATH, f))[-3:] == "tif":
            img = Image.open(join(Config.SINGLE_TEST_PATH, f)).resize((128, 128))
            img = np.array(img, dtype=np.float32) / 128.0
            test[cnt, :, :, 0] = img
            cnt = cnt + 1
    return test

import matplotlib.pyplot as plt


# Update evaluate function to use PyTorch for model prediction
def evaluate_batchwise(model, sequences, batch_size):
    reconstructed_sequences_list = []
    for i in range(0, sequences.size(0), batch_size):
        with torch.no_grad():
            batch = sequences[i:i+batch_size]
            reconstructed_batch = model(batch)
            reconstructed_sequences_list.append(reconstructed_batch)
    return torch.cat(reconstructed_sequences_list, dim=0)

def evaluate():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = get_model(True).to(device)
    test = get_single_test()
    test = torch.tensor(np.array(test)).float().to(device)

    sz = test.size(0) - 10 + 1
    sequences = torch.zeros(sz, 10, 128, 128, 1).to(device)
    for i in range(sz):
        sequences[i] = test[i:i+10].to(device)

    reconstructed_sequences = evaluate_batchwise(model, sequences, batch_size=10)

    sequences_reconstruction_cost = torch.sqrt(torch.sum((sequences - reconstructed_sequences) ** 2, dim=[2,3,4]))

    sa = (sequences_reconstruction_cost - torch.min(sequences_reconstruction_cost)) / torch.max(sequences_reconstruction_cost)
    sr = 1.0 - sa

    plt.plot(sr.cpu().numpy())
    plt.ylabel('regularity score Sr(t)')
    plt.xlabel('frame t')
    plt.show()

# %%
# Call evaluate to test the converted code
# evaluate()

# %%
from collections import OrderedDict
from typing import List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split
from torchvision.datasets import CIFAR10

import flwr as fl
from flwr.common import Metrics

DEVICE = torch.device("cuda")  # Try "cuda" to train on GPU
print(
    f"Training on {DEVICE} using PyTorch {torch.__version__} and Flower {fl.__version__}"
)
# Out:
# Training on cuda using PyTorch 2.1.0+cu118 and Flower 1.5.0

# %%
NUM_CLIENTS = 10
BATCH_SIZE = 2

# %%
def get_test_set():
    test_clips_with_gt = []
    test_clips = []
    gt_clips = []

    if not os.path.exists(Config.TEST_DATA_PATH):
        raise FileNotFoundError(f"Test data path {Config.TEST_DATA_PATH} does not exist")

    for f in sorted(listdir(Config.TEST_DATA_PATH)):
        dir_path = join(Config.TEST_DATA_PATH, f)
        if isdir(dir_path):
            all_frames = []
            all_gt_frames = []  # Initialize here

            # Load normal test sequences
            if not f.endswith('_gt'):
                for c in sorted(listdir(dir_path)):
                    file_path = join(dir_path, c)
                    if file_path.endswith(".tif"):
                        print(f"Attempting to open: {file_path}")  # Debug print
                        if not os.path.isfile(file_path):
                            raise FileNotFoundError(f"Expected file not found: {file_path}")
                        try:
                            img = Image.open(file_path).resize((128, 128))
                            img = np.array(img, dtype=np.float32) / 128.0
                            all_frames.append(img)
                        except IOError as e:
                            print(f"Error opening file {file_path}: {e}")  # Additional error handling

            # Load ground truth sequences
            else:
                for c in sorted(listdir(dir_path)):
                    file_path = join(dir_path, c)
                    if file_path.endswith(".bmp"):
                        print(f"Attempting to open GT file: {file_path}")  # Debug print
                        if not os.path.isfile(file_path):
                            raise FileNotFoundError(f"Expected file not found: {file_path}")
                        try:
                            img = Image.open(file_path).convert('L').resize((128, 128))
                            img = np.array(img, dtype=np.float32) / 255.0  # Normalizing GT images
                            all_gt_frames.append(img)
                        except IOError as e:
                            print(f"Error opening GT file {file_path}: {e}")  # Additional error handling

            # Add to respective lists
            if all_frames:
                for stride in range(1, 3):
                    test_clips.extend(get_clips_by_stride(stride=stride, frames_list=all_frames, sequence_size=10))
            if all_gt_frames:
                for stride in range(1, 3):
                    gt_clips.extend(get_clips_by_stride(stride=stride, frames_list=all_gt_frames, sequence_size=10))
    
    for test_clip, gt_clip in zip(test_clips, gt_clips):
        test_clips_with_gt.append((test_clip, gt_clip))

    return test_clips_with_gt

# %%
def create_dataloader():
    # Load and preprocess the dataset
    training_set = get_training_set()

    # Convert the dataset to a PyTorch Tensor
    training_set_tensor = torch.tensor(training_set).float()

    # Create a TensorDataset
    train_dataset = TensorDataset(training_set_tensor)

    # Create a DataLoader
    train_loader = DataLoader(train_dataset, batch_size=Config.BATCH_SIZE, shuffle=True, num_workers=4)

    return train_loader

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset

def create_test_loader():
    test_clips_with_gt = get_test_set()

    # Create TensorDataset
    test_clips, gt_clips = zip(*test_clips_with_gt)
    test_dataset = TensorDataset(torch.tensor(np.array(test_clips)).float(), 
                                 torch.tensor(np.array(gt_clips)).float())

    # Create DataLoader
    test_loader = DataLoader(test_dataset, batch_size=Config.BATCH_SIZE, shuffle=False, num_workers=4)

    return test_loader

# Usage
# test_loader = create_test_loader()

# %%
def parse_annotations():
    TestVideoFile = [
        {"gt_frame": [60, 152]},
        {"gt_frame": [50, 175]},
        {"gt_frame": [91, 200]},
        {"gt_frame": [31, 168]},
        {"gt_frame": [5, 90, 140, 200]},
        {"gt_frame": [1, 100, 110, 200]},
        {"gt_frame": [1, 175]},
        {"gt_frame": [1, 94]},
        {"gt_frame": [1, 48]},
        {"gt_frame": [1, 140]},
        {"gt_frame": [70, 165]},
        {"gt_frame": [130, 200]},
        {"gt_frame": [1, 156]},
        {"gt_frame": [1, 200]},
        {"gt_frame": [138, 200]},
        {"gt_frame": [123, 200]},
        {"gt_frame": [1, 47]},
        {"gt_frame": [54, 120]},
        {"gt_frame": [64, 138]},
        {"gt_frame": [45, 175]},
        {"gt_frame": [31, 200]},
        {"gt_frame": [16, 107]},
        {"gt_frame": [8, 165]},
        {"gt_frame": [50, 171]},
        {"gt_frame": [40, 135]},
        {"gt_frame": [77, 144]},
        {"gt_frame": [10, 122]},
        {"gt_frame": [105, 200]},
        {"gt_frame": [1, 15, 45, 113]},
        {"gt_frame": [175, 200]},
        {"gt_frame": [1, 180]},
        {"gt_frame": [1, 52, 65, 115]},
        {"gt_frame": [5, 165]},
        {"gt_frame": [1, 121]},
        {"gt_frame": [86, 200]},
        {"gt_frame": [15, 108]},
    ]

    annotations = {}
    for i, video in enumerate(TestVideoFile):
        abnormal_frames = set()
        for start, end in zip(video["gt_frame"][::2], video["gt_frame"][1::2]):
            abnormal_frames.update(range(start, end + 1))
        annotations[i] = abnormal_frames
    return annotations

annotations = parse_annotations()

# %%
import torch
import torch.nn.functional as F

def calculate_metrics(outputs, labels):
    # Assuming outputs and labels are tensors of the same shape
    # Adjust the calculation based on your model's output format
    predicted = outputs.round()  # Assuming model outputs a probability that needs to be rounded to 0 or 1
    correct = (predicted == labels).float()  # Correct predictions
    accuracy = correct.sum() / correct.numel()
    
    # Precision, Recall, and F1 Score can be calculated here as well, depending on your requirement

    return accuracy  #, precision, recall, f1_score

def evaluate(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode

    total_accuracy = 0
    total_loss = 0
    criterion = nn.MSELoss()  # or any other appropriate loss function

    with torch.no_grad():
        for sequences, labels in test_loader:
            sequences, labels = sequences.to(device), labels.to(device)

            outputs = model(sequences)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            accuracy = calculate_metrics(outputs, labels)
            total_accuracy += accuracy.item()

    avg_loss = total_loss / len(test_loader)
    avg_accuracy = total_accuracy / len(test_loader)

    print(f'Evaluation Loss: {avg_loss:.4f}, Accuracy: {avg_accuracy:.4f}')

    return avg_loss, avg_accuracy

# Usage example
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = get_model().to(device)
test_loader = create_test_loader()
evaluate(model, test_loader, device)
# Out:
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\200.tif
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\001.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\002.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\003.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\004.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\005.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\006.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\007.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\008.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\009.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\010.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\011.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\012.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\013.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\014.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\015.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\016.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\017.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\018.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\019.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\020.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\021.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\022.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\023.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\024.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\025.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\026.bmp
# Attempting to open GT file: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003_gt\027.bmp
# ...
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\200.tif
# Evaluation Loss: 0.6519, Accuracy: 0.3183
# (0.6519395890831947, 0.3182889476418495)

# %%
import numpy as np
import os
from os import listdir
from os.path import isdir, join
from PIL import Image
import torch
from torch.utils.data import TensorDataset, DataLoader

def split_dataset(data, num_splits=10):
    """ Split the dataset into num_splits parts. """
    split_size = len(data) // num_splits
    return [data[i*split_size:(i+1)*split_size] for i in range(num_splits)]

def get_training_set():
    clips = []
    for f in sorted(listdir(Config.DATASET_PATH)):
        if isdir(join(Config.DATASET_PATH, f)):
            all_frames = []
            for c in sorted(listdir(join(Config.DATASET_PATH, f))):
                if str(join(join(Config.DATASET_PATH, f), c))[-3:] == "tif":
                    img = Image.open(join(join(Config.DATASET_PATH, f), c)).resize((128, 128))  # Reduced image size
                    img = np.array(img, dtype=np.float32) / 128.0
                    all_frames.append(img)
            for stride in range(1, 3):
                clips.extend(get_clips_by_stride(stride=stride, frames_list=all_frames, sequence_size=10))
    return split_dataset(np.array(clips))  # Split dataset into 10 parts

def get_test_set():
    test_clips_with_gt = []
    test_clips = []
    gt_clips = []

    if not os.path.exists(Config.TEST_DATA_PATH):
        raise FileNotFoundError(f"Test data path {Config.TEST_DATA_PATH} does not exist")

    for f in sorted(listdir(Config.TEST_DATA_PATH)):
        dir_path = join(Config.TEST_DATA_PATH, f)
        if isdir(dir_path):
            all_frames = []
            all_gt_frames = []  # Initialize here

            # Load normal test sequences
            if not f.endswith('_gt'):
                for c in sorted(listdir(dir_path)):
                    file_path = join(dir_path, c)
                    if file_path.endswith(".tif"):
                        print(f"Attempting to open: {file_path}")  # Debug print
                        if not os.path.isfile(file_path):
                            raise FileNotFoundError(f"Expected file not found: {file_path}")
                        try:
                            img = Image.open(file_path).resize((128, 128))
                            img = np.array(img, dtype=np.float32) / 128.0
                            all_frames.append(img)
                        except IOError as e:
                            print(f"Error opening file {file_path}: {e}")  # Additional error handling

            # Load ground truth sequences
            else:
                for c in sorted(listdir(dir_path)):
                    file_path = join(dir_path, c)
                    if file_path.endswith(".bmp"):
                        print(f"Attempting to open GT file: {file_path}")  # Debug print
                        if not os.path.isfile(file_path):
                            raise FileNotFoundError(f"Expected file not found: {file_path}")
                        try:
                            img = Image.open(file_path).convert('L').resize((128, 128))
                            img = np.array(img, dtype=np.float32) / 128.0  # Normalizing GT images
                            all_gt_frames.append(img)
                        except IOError as e:
                            print(f"Error opening GT file {file_path}: {e}")  # Additional error handling

            # Add to respective lists
            if all_frames:
                for stride in range(1, 3):
                    test_clips.extend(get_clips_by_stride(stride=stride, frames_list=all_frames, sequence_size=10))
            if all_gt_frames:
                for stride in range(1, 3):
                    gt_clips.extend(get_clips_by_stride(stride=stride, frames_list=all_gt_frames, sequence_size=10))
    
    for test_clip, gt_clip in zip(test_clips, gt_clips):
        test_clips_with_gt.append((test_clip, gt_clip))
          
    return split_dataset(test_clips_with_gt)  # Split dataset into 10 parts

def create_data_loaders(dataset, batch_size, is_test=False):
    data_loaders = []
    for data_split in dataset:
        if is_test:
            # For test dataset
            test_clips, gt_clips = zip(*data_split)
            test_clips = torch.tensor(np.array(test_clips)).float()
            gt_clips = torch.tensor(np.array(gt_clips)).float()
            # Combine test_clips and gt_clips into a single tensor
            combined = torch.cat((test_clips.unsqueeze(-1), gt_clips.unsqueeze(-1)), dim=1)
            tensor_dataset = TensorDataset(combined)
        else:
            # For training dataset, keep it as 5D tensor
            data_tensor = torch.tensor(np.array(data_split)).float()
            tensor_dataset = TensorDataset(data_tensor)

        loader = DataLoader(tensor_dataset, batch_size=batch_size, shuffle=not is_test, num_workers=4)
        data_loaders.append(loader)
    return data_loaders


simple_dataset = torch.randn(10, 1, 128, 128)  # 10 random 'images'
simple_loader = DataLoader(simple_dataset, batch_size=2)

for batch in simple_loader:
    print(f"Batch type: {type(batch)}, Batch shape: {batch.shape}")
    break


# Usage
train_splits = get_training_set()
for split in train_splits:
    data_tensor = torch.tensor(np.array(split)).float()
    print(f"Data tensor shape: {data_tensor.shape}")
    break  # Just inspect the first split

train_loaders = create_data_loaders(train_splits, Config.BATCH_SIZE)
for batch in train_loaders[0]:
    print(f"Batch type: {type(batch)}, Batch content: {batch}")
    break

test_splits = get_test_set()
test_loaders = create_data_loaders(test_splits, Config.BATCH_SIZE, is_test=True)
# Out:
# Batch type: <class 'torch.Tensor'>, Batch shape: torch.Size([2, 1, 128, 128])
# Data tensor shape: torch.Size([136, 10, 128, 128, 1])
# Batch type: <class 'list'>, Batch content: [tensor([[[[[0.7969],
#            [0.7812],
#            [1.0000],
#            ...,
#            [0.7109],
#            [0.4766],
#            [0.6172]],
#
#           [[0.6875],
#            [0.8125],
#            [1.0000],
#            ...,
#            [0.7578],
#            [0.5156],
#            [0.6719]],
#
#           [[0.8750],
#            [0.7656],
#            [0.8047],
#            ...,
#            [0.8047],
#            [0.6875],
#            [0.7031]],
#
#           ...,
#
#           [[0.6094],
#            [0.9375],
#            [0.9062],
#            ...,
#            [1.4375],
#            [1.4297],
#            [1.5000]],
#
#           [[0.6719],
#            [0.9688],
#            [0.9453],
#            ...,
#            [1.4609],
#            [1.4375],
#            [1.5156]],
#
#           [[0.6953],
#            [0.9922],
#            [1.0000],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.7969],
#            [0.7812],
#            [1.0000],
#            ...,
#            [0.7188],
#            [0.4688],
#            [0.6172]],
#
#           [[0.6875],
#            [0.8203],
#            [1.0000],
#            ...,
#            [0.7578],
#            [0.5312],
#            [0.6719]],
#
#           [[0.8828],
#            [0.7500],
#            [0.8047],
#            ...,
#            [0.7969],
#            [0.6875],
#            [0.7031]],
#
#           ...,
#
#           [[0.5703],
#            [0.8984],
#            [0.9141],
#            ...,
#            [1.4375],
#            [1.4297],
#            [1.5000]],
#
#           [[0.6172],
#            [0.9531],
#            [0.9453],
#            ...,
#            [1.4609],
#            [1.4453],
#            [1.5156]],
#
#           [[0.6484],
#            [0.9844],
#            [0.9922],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.8047],
#            [0.7656],
#            [0.9922],
#            ...,
#            [0.7188],
#            [0.4688],
#            [0.6172]],
#
#           [[0.6953],
#            [0.8203],
#            [1.0000],
#            ...,
#            [0.7656],
#            [0.5312],
#            [0.6641]],
#
#           [[0.8672],
#            [0.7891],
#            [0.8438],
#            ...,
#            [0.8047],
#            [0.6875],
#            [0.6641]],
#
#           ...,
#
#           [[0.5703],
#            [0.5781],
#            [0.9141],
#            ...,
#            [1.4375],
#            [1.4297],
#            [1.4844]],
#
#           [[0.5547],
#            [0.4766],
#            [1.1875],
#            ...,
#            [1.4609],
#            [1.4453],
#            [1.5234]],
#
#           [[0.5781],
#            [0.3359],
#            [0.8438],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          ...,
#
#
#          [[[0.8047],
#            [0.7656],
#            [1.0000],
#            ...,
#            [0.7344],
#            [0.4375],
#            [0.5938]],
#
#           [[0.7031],
#            [0.8281],
#            [1.0078],
#            ...,
#            [0.7656],
#            [0.5000],
#            [0.6250]],
#
#           [[0.8672],
#            [0.7812],
#            [0.8125],
#            ...,
#            [0.8047],
#            [0.6797],
#            [0.8672]],
#
#           ...,
#
#           [[0.8906],
#            [0.8906],
#            [0.6406],
#            ...,
#            [1.4297],
#            [1.4453],
#            [1.5078]],
#
#           [[0.9141],
#            [0.8672],
#            [0.5391],
#            ...,
#            [1.4688],
#            [1.4453],
#            [1.5234]],
#
#           [[0.9219],
#            [0.8984],
#            [0.9297],
#            ...,
#            [1.4844],
#            [1.4453],
#            [1.5391]]],
#
#
#          [[[0.8047],
#            [0.7656],
#            [1.0000],
#            ...,
#            [0.7344],
#            [0.4453],
#            [0.6250]],
#
#           [[0.6953],
#            [0.8203],
#            [1.0156],
#            ...,
#            [0.7656],
#            [0.5078],
#            [0.6094]],
#
#           [[0.8672],
#            [0.7812],
#            [0.8203],
#            ...,
#            [0.7969],
#            [0.6719],
#            [0.8750]],
#
#           ...,
#
#           [[0.8750],
#            [0.8750],
#            [0.9062],
#            ...,
#            [1.4297],
#            [1.4531],
#            [1.5078]],
#
#           [[0.9062],
#            [0.8906],
#            [0.9688],
#            ...,
#            [1.4688],
#            [1.4453],
#            [1.5234]],
#
#           [[0.9375],
#            [0.9453],
#            [0.5000],
#            ...,
#            [1.4844],
#            [1.4453],
#            [1.5391]]],
#
#
#          [[[0.7734],
#            [0.7578],
#            [1.0078],
#            ...,
#            [0.7266],
#            [0.4531],
#            [0.6172]],
#
#           [[0.6797],
#            [0.8125],
#            [1.0156],
#            ...,
#            [0.7578],
#            [0.5156],
#            [0.6172]],
#
#           [[0.8594],
#            [0.7891],
#            [0.8438],
#            ...,
#            [0.7969],
#            [0.6797],
#            [0.8750]],
#
#           ...,
#
#           [[0.8672],
#            [0.8672],
#            [0.8984],
#            ...,
#            [1.4297],
#            [1.4531],
#            [1.5078]],
#
#           [[0.8984],
#            [0.8984],
#            [0.8906],
#            ...,
#            [1.4609],
#            [1.4453],
#            [1.5156]],
#
#           [[0.9297],
#            [0.9297],
#            [0.8984],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]]],
#
#
#
#         [[[[0.7969],
#            [0.7812],
#            [1.0000],
#            ...,
#            [0.7188],
#            [0.4688],
#            [0.6172]],
#
#           [[0.6875],
#            [0.8203],
#            [1.0000],
#            ...,
#            [0.7578],
#            [0.5312],
#            [0.6719]],
#
#           [[0.8828],
#            [0.7500],
#            [0.8047],
#            ...,
#            [0.7969],
#            [0.6875],
#            [0.7031]],
#
#           ...,
#
#           [[0.5703],
#            [0.8984],
#            [0.9141],
#            ...,
#            [1.4375],
#            [1.4297],
#            [1.5000]],
#
#           [[0.6172],
#            [0.9531],
#            [0.9453],
#            ...,
#            [1.4609],
#            [1.4453],
#            [1.5156]],
#
#           [[0.6484],
#            [0.9844],
#            [0.9922],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.8047],
#            [0.7656],
#            [1.0078],
#            ...,
#            [0.7266],
#            [0.4688],
#            [0.6250]],
#
#           [[0.6953],
#            [0.8203],
#            [1.0156],
#            ...,
#            [0.7500],
#            [0.5312],
#            [0.6641]],
#
#           [[0.8750],
#            [0.7734],
#            [0.8281],
#            ...,
#            [0.7969],
#            [0.6953],
#            [0.6562]],
#
#           ...,
#
#           [[0.7969],
#            [0.6172],
#            [0.6562],
#            ...,
#            [1.4375],
#            [1.4297],
#            [1.5000]],
#
#           [[0.7266],
#            [0.5859],
#            [0.5234],
#            ...,
#            [1.4609],
#            [1.4453],
#            [1.5156]],
#
#           [[0.6797],
#            [0.5078],
#            [0.3281],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.8047],
#            [0.7656],
#            [1.0000],
#            ...,
#            [0.7344],
#            [0.4375],
#            [0.6016]],
#
#           [[0.6953],
#            [0.8281],
#            [1.0156],
#            ...,
#            [0.7578],
#            [0.4922],
#            [0.6328]],
#
#           [[0.8672],
#            [0.7812],
#            [0.8203],
#            ...,
#            [0.8047],
#            [0.7031],
#            [0.7422]],
#
#           ...,
#
#           [[0.8984],
#            [0.7109],
#            [0.3672],
#            ...,
#            [1.4453],
#            [1.4297],
#            [1.5000]],
#
#           [[0.9453],
#            [0.7734],
#            [0.7812],
#            ...,
#            [1.4688],
#            [1.4453],
#            [1.5234]],
#
#           [[0.9531],
#            [0.7578],
#            [0.5000],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5469]]],
#
#
#          ...,
#
#
#          [[[0.8047],
#            [0.7656],
#            [1.0000],
#            ...,
#            [0.7266],
#            [0.4688],
#            [0.6250]],
#
#           [[0.6953],
#            [0.8125],
#            [1.0078],
#            ...,
#            [0.7578],
#            [0.4922],
#            [0.6250]],
#
#           [[0.8672],
#            [0.7734],
#            [0.8516],
#            ...,
#            [0.7969],
#            [0.6719],
#            [0.8984]],
#
#           ...,
#
#           [[0.9141],
#            [0.9219],
#            [0.9375],
#            ...,
#            [1.4297],
#            [1.4453],
#            [1.5078]],
#
#           [[0.9688],
#            [0.9844],
#            [0.9688],
#            ...,
#            [1.4609],
#            [1.4375],
#            [1.5156]],
#
#           [[0.9844],
#            [1.0156],
#            [1.0000],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.8359],
#            [0.7891],
#            [0.9922],
#            ...,
#            [0.7344],
#            [0.4609],
#            [0.6250]],
#
#           [[0.6719],
#            [0.7969],
#            [1.0234],
#            ...,
#            [0.7578],
#            [0.5156],
#            [0.6094]],
#
#           [[0.8438],
#            [0.7656],
#            [0.8672],
#            ...,
#            [0.8047],
#            [0.6797],
#            [0.8750]],
#
#           ...,
#
#           [[0.9375],
#            [0.9453],
#            [0.9375],
#            ...,
#            [1.4297],
#            [1.4453],
#            [1.5078]],
#
#           [[0.9844],
#            [1.0000],
#            [0.9844],
#            ...,
#            [1.4609],
#            [1.4375],
#            [1.5156]],
#
#           [[1.0078],
#            [1.0234],
#            [1.0000],
#            ...,
#            [1.4922],
#            [1.4531],
#            [1.5391]]],
#
#
#          [[[0.8359],
#            [0.7969],
#            [0.9844],
#            ...,
#            [0.7266],
#            [0.4766],
#            [0.6328]],
#
#           [[0.6719],
#            [0.7891],
#            [1.0234],
#            ...,
#            [0.7578],
#            [0.5078],
#            [0.6094]],
#
#           [[0.8438],
#            [0.7500],
#            [0.8516],
#            ...,
#            [0.7969],
#            [0.6797],
#            [0.8828]],
#
#           ...,
#
#           [[0.9453],
#            [0.9375],
#            [0.9375],
#            ...,
#            [1.4219],
#            [1.4453],
#            [1.5078]],
#
#           [[0.9844],
#            [0.9844],
#            [0.9922],
#            ...,
#            [1.4688],
#            [1.4375],
#            [1.5156]],
#
#           [[1.0078],
#            [1.0078],
#            [1.0000],
#            ...,
#            [1.4844],
#            [1.4453],
#            [1.5391]]]]])]
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test001\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test002\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test003\089.tif
# ...
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test035\200.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\001.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\002.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\003.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\004.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\005.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\006.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\007.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\008.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\009.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\010.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\011.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\012.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\013.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\014.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\015.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\016.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\017.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\018.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\019.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\020.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\021.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\022.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\023.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\024.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\025.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\026.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\027.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\028.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\029.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\030.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\031.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\032.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\033.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\034.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\035.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\036.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\037.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\038.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\039.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\040.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\041.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\042.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\043.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\044.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\045.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\046.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\047.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\048.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\049.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\050.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\051.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\052.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\053.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\054.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\055.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\056.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\057.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\058.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\059.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\060.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\061.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\062.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\063.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\064.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\065.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\066.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\067.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\068.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\069.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\070.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\071.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\072.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\073.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\074.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\075.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\076.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\077.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\078.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\079.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\080.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\081.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\082.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\083.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\084.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\085.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\086.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\087.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\088.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\089.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\090.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\091.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\092.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\093.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\094.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\095.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\096.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\097.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\098.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\099.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\100.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\101.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\102.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\103.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\104.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\105.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\106.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\107.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\108.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\109.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\110.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\111.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\112.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\113.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\114.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\115.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\116.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\117.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\118.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\119.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\120.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\121.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\122.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\123.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\124.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\125.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\126.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\127.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\128.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\129.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\130.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\131.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\132.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\133.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\134.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\135.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\136.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\137.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\138.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\139.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\140.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\141.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\142.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\143.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\144.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\145.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\146.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\147.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\148.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\149.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\150.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\151.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\152.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\153.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\154.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\155.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\156.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\157.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\158.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\159.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\160.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\161.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\162.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\163.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\164.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\165.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\166.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\167.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\168.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\169.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\170.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\171.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\172.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\173.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\174.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\175.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\176.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\177.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\178.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\179.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\180.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\181.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\182.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\183.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\184.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\185.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\186.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\187.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\188.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\189.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\190.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\191.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\192.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\193.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\194.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\195.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\196.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\197.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\198.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\199.tif
# Attempting to open: UCSD_Anomaly_Dataset.v1p2/UCSDped1/Test\Test036\200.tif

# %%
class ConvLSTMCell(nn.Module):
    def __init__(self, input_size, hidden_size, kernel_size):
        super(ConvLSTMCell, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.kernel_size = kernel_size
        self.padding = kernel_size // 2
        self.conv = nn.Conv2d(input_size + hidden_size, 4 * hidden_size, kernel_size, 1, self.padding)

    def forward(self, x, state):
        h_cur, c_cur = state
        combined = torch.cat([x, h_cur], dim=1)
        gates = self.conv(combined)
        ingate, forgetgate, cellgate, outgate = gates.chunk(4, 1)
        ingate = torch.sigmoid(ingate)
        forgetgate = torch.sigmoid(forgetgate)
        cellgate = torch.tanh(cellgate)
        outgate = torch.sigmoid(outgate)

        c_next = (forgetgate * c_cur) + (ingate * cellgate)
        h_next = outgate * torch.tanh(c_next)

        return h_next, c_next
    
    def initialize_hidden_state(self, batch_size, image_size):
        height, width = image_size
        return (torch.zeros(batch_size, self.hidden_size, height, width, device=self.conv.weight.device),
                torch.zeros(batch_size, self.hidden_size, height, width, device=self.conv.weight.device))


class SimplifiedAnomalyDetectionModel(nn.Module):
    def __init__(self):
        super(SimplifiedAnomalyDetectionModel, self).__init__()
        # Encoder - simplified
        self.encoder_conv1 = nn.Conv2d(1, 64, kernel_size=5, stride=2, padding=2)
        self.encoder_conv_lstm = ConvLSTM(64, 32, kernel_size=3, num_layers=1)

        # Decoder - simplified
        self.decoder_conv_transpose = nn.ConvTranspose2d(32, 64, kernel_size=5, stride=2, padding=2, output_padding=1)
        self.decoder_conv2 = nn.Conv2d(64, 1, kernel_size=5, padding=2)

    def forward(self, x):
        # Reshape for time distributed operations
        b, t, h, w, c = x.size()
        x = x.view(b*t, c, h, w)
        
        # Encoder
        x = self.encoder_conv1(x)
        
        # Reshape for LSTM layer
        x = x.view(b, t, x.size(1), x.size(2), x.size(3))
        
        x, _ = self.encoder_conv_lstm(x)

        # Reshape for decoder conv layers
        x = x.view(b*t, x.size(2), x.size(3), x.size(4))
        
        # Decoder
        x = self.decoder_conv_transpose(x)
        x = self.decoder_conv2(x)

        x = x[:, :, :128, :128]

        # Reshape back to original shape
        x = x.view(b, t, h, w, c)
        
        return x

# %%
def train_model_2(model, train_loader, optimizer, criterion, device, local_epochs):
    model.train()
    for epoch in range(local_epochs):
        epoch_loss = 0.0
        for batch in train_loader:  # Now, batch is a list containing a single tensor
            sequences = batch[0].to(device)  # Extract the tensor and move it to the device

            optimizer.zero_grad()

            # Since your model seems to accept 5D tensors, ensure sequences is in that shape
            # sequences should be of shape [batch, time_steps, height, width, channels]
            outputs = model(sequences)

            # Reshape as necessary for the loss function
            b, t, h, w, c = sequences.size()
            loss = criterion(outputs.view(b * t, c, h, w), sequences.view(b * t, c, h, w))
            loss.backward()

            optimizer.step()
            epoch_loss += loss.item()

        avg_epoch_loss = epoch_loss / len(train_loader)
        print(f"Local Epoch [{epoch+1}/{local_epochs}], Loss: {avg_epoch_loss:.4f}")

# %%
def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]


def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

# %%
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model = SimplifiedAnomalyDetectionModel().to(device)
        optimizer = optim.Adam(model.parameters(), lr=1e-4)
        criterion = nn.MSELoss()
        train_model_2(self.net, self.trainloader, optimizer, criterion, device, local_epochs=1)
        return get_parameters(self.net), len(self.trainloader), {}
    
    
    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        loss, accuracy = evaluate(self.net, self.valloader, device)  # Modify this function to handle the new data format
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %%
def client_fn(cid: str) -> FlowerClient:
    """Create a Flower client representing a single organization."""

    # Load model
    net = AnomalyDetectionModel().to(DEVICE)

    # Load data (CIFAR-10)
    # Note: each client gets a different trainloader/valloader, so each client
    # will train and evaluate on their own unique data
    trainloader = train_loaders[int(cid)]
    valloader = test_loaders[int(cid)]

    # Create a  single Flower client representing a single organization
    return FlowerClient(net, trainloader, valloader)

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,  # Sample 100% of available clients for training
    fraction_evaluate=0.5,  # Sample 50% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=10,  # Wait until all 10 clients are available
)

# Specify client resources if you need GPU (defaults to 1 CPU and 0 GPU)
client_resources = None
if DEVICE.type == "cuda":
    client_resources = {"num_cpus": 1, "num_gpus": 0}

"""

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
"""
# Out:
# '\n\n# Start simulation\nfl.simulation.start_simulation(\n    client_fn=client_fn,\n    num_clients=NUM_CLIENTS,\n    config=fl.server.ServerConfig(num_rounds=5),\n    strategy=strategy,\n    client_resources=client_resources,\n)\n'

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}

# %%
# Create FedAvg strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_evaluate=0.5,
    min_fit_clients=10,
    min_evaluate_clients=5,
    min_available_clients=10,
    evaluate_metrics_aggregation_fn=weighted_average,  # <-- pass the metric aggregation function
)

# Start simulation
fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    config=fl.server.ServerConfig(num_rounds=5),
    strategy=strategy,
    client_resources=client_resources,
)
# Out:
# INFO flwr 2023-11-18 21:41:50,920 | app.py:175 | Starting Flower simulation, config: ServerConfig(num_rounds=5, round_timeout=None)
# 2023-11-18 21:41:56,285	INFO worker.py:1621 -- Started a local Ray instance.
# INFO flwr 2023-11-18 21:42:03,938 | app.py:210 | Flower VCE: Ray initialized with resources: {'CPU': 16.0, 'node:__internal_head__': 1.0, 'memory': 2333021799.0, 'object_store_memory': 1166510899.0, 'node:127.0.0.1': 1.0, 'GPU': 1.0}
# INFO flwr 2023-11-18 21:42:03,938 | app.py:224 | Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0}
# INFO flwr 2023-11-18 21:42:03,970 | app.py:270 | Flower VCE: Creating VirtualClientEngineActorPool with 16 actors
# INFO flwr 2023-11-18 21:42:03,970 | server.py:89 | Initializing global parameters
# INFO flwr 2023-11-18 21:42:03,978 | server.py:276 | Requesting initial parameters from one random client
# INFO flwr 2023-11-18 21:42:47,375 | server.py:280 | Received initial parameters from one random client
# INFO flwr 2023-11-18 21:42:47,383 | server.py:91 | Evaluating initial parameters
# INFO flwr 2023-11-18 21:42:47,383 | server.py:104 | FL starting
# DEBUG flwr 2023-11-18 21:42:47,383 | server.py:222 | fit_round 1: strategy sampled 10 clients (out of 10)
# (DefaultActor pid=13156) Local Epoch [1/1], Loss: 0.7042
# (DefaultActor pid=14924) Local Epoch [1/1], Loss: 0.6836
# (DefaultActor pid=12344) Local Epoch [1/1], Loss: 0.7146
# (DefaultActor pid=16808) Local Epoch [1/1], Loss: 0.7231
# (DefaultActor pid=4976)
# (DefaultActor pid=4976) Traceback (most recent call last):
# (DefaultActor pid=4976)   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 387, in deserialize_objects
# (DefaultActor pid=4976)     obj = self._deserialize_object(data, metadata, object_ref)
# (DefaultActor pid=4976)           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DefaultActor pid=4976)   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 268, in _deserialize_object
# (DefaultActor pid=4976)     return self._deserialize_msgpack_data(data, metadata_fields)
# (DefaultActor pid=4976)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DefaultActor pid=4976)   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 223, in _deserialize_msgpack_data
# (DefaultActor pid=4976)     python_objects = self._deserialize_pickle5_data(pickle5_data)
# (DefaultActor pid=4976)                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (DefaultActor pid=4976)   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 213, in _deserialize_pickle5_data
# (DefaultActor pid=4976)     obj = pickle.loads(in_band)
# (DefaultActor pid=4976)           ^^^^^^^^^^^^^^^^^^^^^
# (DefaultActor pid=4976) MemoryError
# (DefaultActor pid=15476) fatal   : Memory allocation failure
# 2023-11-18 21:51:45,481	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::DefaultActor.run() (pid=4976, ip=127.0.0.1, actor_id=55b6258580766633beee096b01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x00000222EDDFC450>)
#   File "python\ray\_raylet.pyx", line 1370, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1404, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 753, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error:
# traceback: Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 387, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 268, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 223, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 213, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
#           ^^^^^^^^^^^^^^^^^^^^^
# MemoryError
# ERROR flwr 2023-11-18 21:51:49,887 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 137, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 253, in submit_client_job
#     self.submit(actor_fn, job)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 231, in submit
#     future = fn(actor, job_fn, cid)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 138, in <lambda>
#     lambda a, v, cid: a.run.remote(v, cid), (job_fn, self.cid)
#                       ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 177, in invocation
#     return actor._actor_method_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "python\ray\_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 687, in ray._raylet.prepare_args_internal
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 468, in serialize
#     return self._serialize_to_msgpack(value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 446, in _serialize_to_msgpack
#     pickle5_serialized_object = self._serialize_to_pickle5(
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 408, in _serialize_to_pickle5
#     raise e
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 403, in _serialize_to_pickle5
#     inband = pickle.dumps(
#              ^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 88, in dumps
#     cp.dump(obj)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 733, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# MemoryError
#
# ERROR flwr 2023-11-18 21:51:50,463 | ray_client_proxy.py:148 |
# 2023-11-18 21:51:50,471	ERROR worker.py:405 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#                   ^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#            ^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\3168360807.py", line 16, in fit
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\1231187224.py", line 17, in train_model_2
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py", line 492, in backward
#     torch.autograd.backward(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py", line 251, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 5 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n           ^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n           ^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\3168360807.py", line 16, in fit\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\1231187224.py", line 17, in train_model_2\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\_tensor.py", line 492, in backward\n    torch.autograd.backward(\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\autograd\\__init__.py", line 251, in backward\n    Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass\nRuntimeError: CUDA error: unknown error\nCUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.\nFor debugging consider passing CUDA_LAUNCH_BLOCKING=1.\nCompile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.\n\n',)
# ERROR flwr 2023-11-18 21:51:50,483 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 137, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 253, in submit_client_job
#     self.submit(actor_fn, job)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 231, in submit
#     future = fn(actor, job_fn, cid)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 138, in <lambda>
#     lambda a, v, cid: a.run.remote(v, cid), (job_fn, self.cid)
#                       ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 177, in invocation
#     return actor._actor_method_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "python\ray\_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 687, in ray._raylet.prepare_args_internal
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 468, in serialize
#     return self._serialize_to_msgpack(value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 446, in _serialize_to_msgpack
#     pickle5_serialized_object = self._serialize_to_pickle5(
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 408, in _serialize_to_pickle5
#     raise e
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 403, in _serialize_to_pickle5
#     inband = pickle.dumps(
#              ^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 88, in dumps
#     cp.dump(obj)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 733, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# MemoryError
#
# ERROR flwr 2023-11-18 21:51:50,668 | ray_client_proxy.py:148 |
# ERROR flwr 2023-11-18 21:51:52,261 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 137, in _submit_job
#     self.actor_pool.submit_client_job(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 253, in submit_client_job
#     self.submit(actor_fn, job)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 231, in submit
#     future = fn(actor, job_fn, cid)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 138, in <lambda>
#     lambda a, v, cid: a.run.remote(v, cid), (job_fn, self.cid)
#                       ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 144, in remote
#     return self._remote(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 423, in _start_span
#     return method(self, args, kwargs, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 190, in _remote
#     return invocation(args, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 177, in invocation
#     return actor._actor_method_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\actor.py", line 1175, in _actor_method_call
#     object_refs = worker.core_worker.submit_actor_task(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "python\ray\_raylet.pyx", line 3350, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 3355, in ray._raylet.CoreWorker.submit_actor_task
#   File "python\ray\_raylet.pyx", line 649, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 640, in ray._raylet.prepare_args_and_increment_put_refs
#   File "python\ray\_raylet.pyx", line 687, in ray._raylet.prepare_args_internal
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 468, in serialize
#     return self._serialize_to_msgpack(value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 446, in _serialize_to_msgpack
#     pickle5_serialized_object = self._serialize_to_pickle5(
#                                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 408, in _serialize_to_pickle5
#     raise e
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 403, in _serialize_to_pickle5
#     inband = pickle.dumps(
#              ^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 88, in dumps
#     cp.dump(obj)
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\cloudpickle\cloudpickle_fast.py", line 733, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
# MemoryError
#
# ERROR flwr 2023-11-18 21:51:52,265 | ray_client_proxy.py:148 |
# ERROR flwr 2023-11-18 21:51:52,478 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError: ray::DefaultActor.run() (pid=4976, ip=127.0.0.1, actor_id=55b6258580766633beee096b01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x00000222EDDFC450>)
#   File "python\ray\_raylet.pyx", line 1370, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1404, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 753, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error:
# traceback: Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 387, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 268, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 223, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 213, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
#           ^^^^^^^^^^^^^^^^^^^^^
# MemoryError
#
# ERROR flwr 2023-11-18 21:51:52,487 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=4976, ip=127.0.0.1, actor_id=55b6258580766633beee096b01000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x00000222EDDFC450>)
#   File "python\ray\_raylet.pyx", line 1370, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1404, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 753, in ray._raylet.raise_if_dependency_failed
# ray.exceptions.RaySystemError: System error:
# traceback: Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 387, in deserialize_objects
#     obj = self._deserialize_object(data, metadata, object_ref)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 268, in _deserialize_object
#     return self._deserialize_msgpack_data(data, metadata_fields)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 223, in _deserialize_msgpack_data
#     python_objects = self._deserialize_pickle5_data(pickle5_data)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\serialization.py", line 213, in _deserialize_pickle5_data
#     obj = pickle.loads(in_band)
#           ^^^^^^^^^^^^^^^^^^^^^
# MemoryError
# ERROR flwr 2023-11-18 21:51:52,491 | ray_client_proxy.py:147 | Traceback (most recent call last):
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 140, in _submit_job
#     res = self.actor_pool.get_client_result(self.cid, timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 402, in get_client_result
#     return self._fetch_future_result(cid)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 288, in _fetch_future_result
#     res_cid, res = ray.get(future)  # type: (str, ClientRes)
#                    ^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\auto_init_hook.py", line 24, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\worker.py", line 2524, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientException): ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#                   ^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#            ^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\3168360807.py", line 16, in fit
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\1231187224.py", line 17, in train_model_2
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py", line 492, in backward
#     torch.autograd.backward(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py", line 251, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 5 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n           ^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n           ^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\3168360807.py", line 16, in fit\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\1231187224.py", line 17, in train_model_2\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\_tensor.py", line 492, in backward\n    torch.autograd.backward(\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\autograd\\__init__.py", line 251, in backward\n    Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass\nRuntimeError: CUDA error: unknown error\nCUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.\nFor debugging consider passing CUDA_LAUNCH_BLOCKING=1.\nCompile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.\n\n',)
#
# ERROR flwr 2023-11-18 21:51:52,491 | ray_client_proxy.py:148 | ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#                   ^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_client_proxy.py", line 196, in fit
#     return maybe_call_fit(
#            ^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\client.py", line 217, in maybe_call_fit
#     return client.fit(fit_ins)
#            ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\client\app.py", line 333, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\3168360807.py", line 16, in fit
#   File "C:\Users\akank\AppData\Local\Temp\ipykernel_11384\1231187224.py", line 17, in train_model_2
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py", line 492, in backward
#     torch.autograd.backward(
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py", line 251, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# The above exception was the direct cause of the following exception:
#
# ray::DefaultActor.run() (pid=15476, ip=127.0.0.1, actor_id=464214ce31245734378e459701000000, repr=<flwr.simulation.ray_transport.ray_actor.DefaultActor object at 0x0000023CF383C450>)
#   File "python\ray\_raylet.pyx", line 1418, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1498, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1424, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1364, in ray._raylet.execute_task.function_executor
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\_private\function_manager.py", line 726, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\ray\util\tracing\tracing_helper.py", line 464, in _resume_span
#     return method(self, *_args, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\akank\AppData\Local\Programs\Python\Python311\Lib\site-packages\flwr\simulation\ray_transport\ray_actor.py", line 72, in run
#     raise ClientException(str(message)) from ex
# flwr.simulation.ray_transport.ray_actor.ClientException:
# >>>>>>>A ClientException occurred.('\n\tSomething went wrong when running your client workload.\n\tClient 5 crashed when the DefaultActor was running its workload.\n\tException triggered on the client side: Traceback (most recent call last):\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_actor.py", line 60, in run\n    job_results = job_fn()\n                  ^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\simulation\\ray_transport\\ray_client_proxy.py", line 196, in fit\n    return maybe_call_fit(\n           ^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\client.py", line 217, in maybe_call_fit\n    return client.fit(fit_ins)\n           ^^^^^^^^^^^^^^^^^^^\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\flwr\\client\\app.py", line 333, in _fit\n    results = self.numpy_client.fit(parameters, ins.config)  # type: ignore\n              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\3168360807.py", line 16, in fit\n  File "C:\\Users\\akank\\AppData\\Local\\Temp\\ipykernel_11384\\1231187224.py", line 17, in train_model_2\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\_tensor.py", line 492, in backward\n    torch.autograd.backward(\n  File "c:\\Users\\akank\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\torch\\autograd\\__init__.py", line 251, in backward\n    Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass\nRuntimeError: CUDA error: unknown error\nCUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.\nFor debugging consider passing CUDA_LAUNCH_BLOCKING=1.\nCompile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.\n\n',)
